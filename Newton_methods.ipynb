# %% [markdown]
# # LAB: (quasi-) Newton methods
#
# Author : Alexandre Gramfort
#
# The objective of this lab session is to implement:
# - Newton method
# - DFP
# - BFGS
# and compare your implementation with the BFGS and L-BFGS solvers in scipy
#
# You will need to knowledge on **line search methods** and **conjugate gradient** in particular you should reuse the notebooks presented during the lectures.
#
# ## VERY IMPORTANT
#
# - This work **must be done by pairs of students**.
# - **Each** student must send their work **before the 30th of october at 23:59**, using the **moodle platform**.
# - This means that **each student in the pair sends the same file**
# - On the moodle, in the "Optimization for Data Science" course, you have a "devoir" section called **Rendu TP du 24 octobre 2016**. This is where you submit your jupyter notebook file.
# - The **name of the file must be** constructed as in the next cell
#
# # Gentle reminder: no evaluation if you don't respect this EXACTLY
#
# ### How to construct the name of your file

# %%
# Change here using YOUR first and last names
fn1 = "salma"
ln1 = "el-alaoui-talibi"
fn2 = "sophia"
ln2 = "lazraq"

filename = "_".join(map(lambda s: s.strip().lower(), 
                        ["tp_newton", ln1, fn1, "and", ln2, fn2])) + ".ipynb"
print(filename)
# Out:
# tp_newton_el-alaoui-talibi_salma_and_lazraq_sophia.ipynb

# %% [markdown]
# # Part 0: Demo using Gradient descent
#
# First import the necessary libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize, linalg

# %matplotlib inline

# %% [markdown]
# Now import the necessary function from the optim_utils.py file.

# %%
from optim_utils import test_solver

# %% [markdown]
# You'll have work only with the `test_solver` function.
#
# This function expects a function as parameter.
#
# The signature of the function `optimizer` to pass should be the following:
#
# `optimizer(x0, f, f_grad, f_hessian)`
#
# Let us now make an example with a gradient descent.

# %%
def gradient_descent(x0, f, f_grad, f_hessian=None):

    default_step = 0.01
    c1 = 0.0001
    c2 = 0.9
    max_iter = 100
    
    # This variable is used to indicate whether or not we want to print
    # monitoring information (iteration counter, function value and norm of the gradient)
    verbose = False

    all_x_k, all_f_k = list(), list()
    x = x0

    all_x_k.append(x.copy())
    all_f_k.append(f(x))

    for k in range(1, max_iter + 1):

        grad_x = f_grad(x)

        # Compute a step size using a line_search to satisfy the
        # strong Wolfe conditions
        step, _, _, new_f, _, new_grad = optimize.line_search(f, f_grad, x,
                                                              -grad_x, grad_x,
                                                              c1=c1, c2=c2)
        if step is None:
            print("Line search did not converge at iteration %s" % k)
            step = default_step

        x -= step * grad_x

        all_x_k.append(x.copy())
        all_f_k.append(new_f)

        l_inf_norm_grad = np.max(np.abs(new_grad))

        if verbose:
            print('iter: %d, f: %.6g, l_inf_norm(grad): %.6g' %
                  (k, new_f, l_inf_norm_grad))

        if l_inf_norm_grad < 1e-6:
            break

    return np.array(all_x_k), np.array(all_f_k)

# %% [markdown]
# Now I can call the `test_solver` function with this solver:

# %%
test_solver(gradient_descent)
# Out:
# Running solver on case 1
#
# Running solver on case 2
#
# Running solver on case 3

# %% [markdown]
# # Part 2: Implement Newton method
#
# You now need to implement Newton method using either `linalg.solve` or `sparse.linalg.cg` solve the linear system at each iteration. You need to implement both versions.
#
# You're expected to comment in a few lines what you see.

# %%
import scipy.linalg as linalg
import scipy as scipy

def newton(x0, f, f_grad, f_hessian):
    default_step = 0.01
    c1 = 0.0001
    c2 = 0.9
    max_iter = 100
    
    # This variable is used to indicate whether or not we want to print
    # monitoring information (iteration counter, function value and norm of the gradient)
    verbose = True

    all_x_k, all_f_k = list(), list()
    x = x0

    all_x_k.append(x.copy())
    all_f_k.append(f(x))

    for k in range(1, max_iter + 1):

        grad_x = f_grad(x)
        
        ####################################
        # Compute here the search direction
        # d = ...
        ####################################
        
        #d = linalg.solve(-f_hessian(x), grad_x)
        d, _ = scipy.sparse.linalg.cg(-f_hessian(x), grad_x)
        
        # Compute a step size using a line_search to satisfy the
        # strong Wolfe conditions
        step, _, _, new_f, _, new_grad = optimize.line_search(f, f_grad, x,
                                                              d, grad_x, c1=c1, c2=c2)
        
        if step is None:
            print("Line search did not converge at iteration %s" % k)
            step = default_step

        ##################################
        # Compute here the new value of x
        # x = ...
        ##################################
        x += step * d
        all_x_k.append(x.copy())
        all_f_k.append(new_f)

        l_inf_norm_grad = np.max(np.abs(new_grad))

        if verbose:
            print('iter: %d, f: %.6g, l_inf_norm(grad): %.6g' %
                  (k, new_f, l_inf_norm_grad))

        if l_inf_norm_grad < 1e-6:
            break

    return np.array(all_x_k), np.array(all_f_k)

# %%
test_solver(newton)
# Out:
# Running solver on case 1
# iter: 1, f: 0, l_inf_norm(grad): 0
#
# Running solver on case 2
# iter: 1, f: 3.40668e-26, l_inf_norm(grad): 2.12057e-13
#
# Running solver on case 3
# iter: 1, f: 0.357547, l_inf_norm(grad): 1.19858
# iter: 2, f: 0.253454, l_inf_norm(grad): 14.6168
# iter: 3, f: 0.137976, l_inf_norm(grad): 3.9843
# iter: 4, f: 0.088137, l_inf_norm(grad): 6.14586
# iter: 5, f: 0.0414804, l_inf_norm(grad): 3.93321
# iter: 6, f: 0.0162138, l_inf_norm(grad): 2.7976
# iter: 7, f: 0.00446914, l_inf_norm(grad): 1.29953
# iter: 8, f: 0.000705202, l_inf_norm(grad): 0.668389
# iter: 9, f: 3.34966e-05, l_inf_norm(grad): 0.121298
# iter: 10, f: 1.24866e-07, l_inf_norm(grad): 0.00982241
# iter: 11, f: 2.01025e-12, l_inf_norm(grad): 3.05844e-05
# iter: 12, f: 5.2958e-22, l_inf_norm(grad): 6.41073e-10

# %% [markdown]
# #### Comments
#
# As expected, we can see that the newton method converges in one iterations for the two quadratic functions, independently of the conditioning of the functions. For the Rosenbrock function, which very ill conditioned, it converges in only 12 iterations.

# %% [markdown]
# # Part 2: Implement DFP algorithm
#
# You now need to implement the DFP algorithm.

# %%
def dfp(x0, f, f_grad, f_hessian):
    default_step = 0.01
    c1 = 0.0001
    c2 = 0.95
    max_iter = 200
    
    # This variable is used to indicate whether or not we want to print
    # monitoring information (iteration counter, function value and norm of the gradient)
    verbose = True

    all_x_k, all_f_k = list(), list()
    x = x0

    all_x_k.append(x.copy())
    all_f_k.append(f(x))

    B = np.eye(len(x))  # inverse Hessian approximation

    grad_x = f_grad(x)
    
    for k in range(1, max_iter + 1):       
        
        ####################################
        # Compute here the search direction
        # d = ...
        ####################################    
        d = -np.dot(B, grad_x)
        
        # Compute a step size using a line_search to satisfy the
        # strong Wolfe conditions
        step, _, _, new_f, _, new_grad = optimize.line_search(f, f_grad, x,
                                                              d, grad_x,
                                                              c1=c1, c2=c2)
        
        if step is None:
            print("Line search did not converge at iteration %s" % k)
            step = default_step

        ##################################
        # Compute here the new value of x
        # x = ...
        ##################################
        x += step * d
        #########################################################
        # Update the inverse Hessian approximation
        # B = ...
        #########################################################
        s = step * d
        s = s[:, None]
        y = new_grad - grad_x
        y = y[:, None]
        B = B + np.dot(s, s.T)/np.dot(s.T, y) - np.dot(B, np.dot(y, np.dot(y.T,B)))/ np.dot(y.T, np.dot(B,y))
        
        all_x_k.append(x.copy())
        all_f_k.append(new_f)

        l_inf_norm_grad = np.max(np.abs(new_grad))

        if verbose:
            print('iter: %d, f: %.6g, l_inf_norm(grad): %.6g' %
                  (k, new_f, l_inf_norm_grad))

        if l_inf_norm_grad < 1e-6:
            break
            
        grad_x = new_grad

    return np.array(all_x_k), np.array(all_f_k)

# %%
test_solver(dfp)
# Out:
# Running solver on case 1
# iter: 1, f: 0.187228, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.0214911, l_inf_norm(grad): 0.114753
# iter: 3, f: 0.00899657, l_inf_norm(grad): 0.069501
# iter: 4, f: 0.00023476, l_inf_norm(grad): 0.0175216
# iter: 5, f: 1.76801e-05, l_inf_norm(grad): 0.00465113
# iter: 6, f: 3.20353e-08, l_inf_norm(grad): 0.000140183
# iter: 7, f: 1.32183e-10, l_inf_norm(grad): 8.99094e-06
# iter: 8, f: 8.82459e-15, l_inf_norm(grad): 1.04309e-07
#
# Running solver on case 2
# iter: 1, f: 0.0978185, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.000159508, l_inf_norm(grad): 0.000290207
# iter: 3, f: 0.000138677, l_inf_norm(grad): 0.000270594
# iter: 4, f: 1.92681e-07, l_inf_norm(grad): 0.000503909
# iter: 5, f: 1.4273e-07, l_inf_norm(grad): 0.000433799
# iter: 6, f: 3.512e-14, l_inf_norm(grad): 1.6706e-08
#
# Running solver on case 3
# iter: 1, f: 104.123, l_inf_norm(grad): 700.972
# iter: 2, f: 7.56575, l_inf_norm(grad): 24.138
# iter: 3, f: 7.34339, l_inf_norm(grad): 4.87789
# iter: 4, f: 7.29892, l_inf_norm(grad): 8.49613
# iter: 5, f: 7.15594, l_inf_norm(grad): 36.0441
# iter: 6, f: 7.12028, l_inf_norm(grad): 29.7927
# iter: 7, f: 7.07565, l_inf_norm(grad): 21.7636
# iter: 8, f: 7.0346, l_inf_norm(grad): 13.9863
# iter: 9, f: 6.99495, l_inf_norm(grad): 6.40059
# iter: 10, f: 6.95511, l_inf_norm(grad): 1.92225
# iter: 11, f: 6.9128, l_inf_norm(grad): 8.52847
# iter: 12, f: 6.86525, l_inf_norm(grad): 16.3458
# iter: 13, f: 6.80303, l_inf_norm(grad): 25.1878
# iter: 14, f: 4.32808, l_inf_norm(grad): 16.571
# iter: 15, f: 4.32751, l_inf_norm(grad): 17.4094
# iter: 16, f: 4.23644, l_inf_norm(grad): 17.1687
# iter: 17, f: 3.90561, l_inf_norm(grad): 22.0984
# iter: 18, f: 3.8858, l_inf_norm(grad): 26.0065
# iter: 19, f: 3.86484, l_inf_norm(grad): 24.2316
# iter: 20, f: 3.84112, l_inf_norm(grad): 22.1615
# iter: 21, f: 3.81443, l_inf_norm(grad): 19.3347
# iter: 22, f: 3.79244, l_inf_norm(grad): 16.6906
# iter: 23, f: 3.77036, l_inf_norm(grad): 13.6039
# iter: 24, f: 3.75141, l_inf_norm(grad): 10.7818
# iter: 25, f: 3.73233, l_inf_norm(grad): 7.72086
# iter: 26, f: 3.71487, l_inf_norm(grad): 4.96043
# iter: 27, f: 3.69639, l_inf_norm(grad): 1.99327
# iter: 28, f: 3.67852, l_inf_norm(grad): 2.48319
# iter: 29, f: 3.65853, l_inf_norm(grad): 4.14144
# iter: 30, f: 3.63757, l_inf_norm(grad): 6.49931
# iter: 31, f: 3.61073, l_inf_norm(grad): 9.75467
# iter: 32, f: 1.9805, l_inf_norm(grad): 6.57641
# iter: 33, f: 1.98011, l_inf_norm(grad): 6.31718
# iter: 34, f: 1.93293, l_inf_norm(grad): 6.14775
# iter: 35, f: 1.73471, l_inf_norm(grad): 7.39226
# iter: 36, f: 1.724, l_inf_norm(grad): 9.78116
# iter: 37, f: 1.7113, l_inf_norm(grad): 8.66638
# iter: 38, f: 1.70041, l_inf_norm(grad): 7.90344
# iter: 39, f: 1.68238, l_inf_norm(grad): 6.30036
# iter: 40, f: 1.67167, l_inf_norm(grad): 5.35466
# iter: 41, f: 1.65832, l_inf_norm(grad): 4.65679
# iter: 42, f: 1.64879, l_inf_norm(grad): 4.12586
# iter: 43, f: 1.63751, l_inf_norm(grad): 3.38139
# iter: 44, f: 1.62863, l_inf_norm(grad): 2.8337
# iter: 45, f: 1.61776, l_inf_norm(grad): 2.10694
# iter: 46, f: 1.6087, l_inf_norm(grad): 1.78064
# iter: 47, f: 1.59705, l_inf_norm(grad): 3.12101
# iter: 48, f: 1.58653, l_inf_norm(grad): 4.22924
# iter: 49, f: 1.5718, l_inf_norm(grad): 5.77496
# iter: 50, f: 1.55127, l_inf_norm(grad): 7.58151
# iter: 51, f: 0.684444, l_inf_norm(grad): 3.10335
# iter: 52, f: 0.68442, l_inf_norm(grad): 3.19276
# iter: 53, f: 0.655269, l_inf_norm(grad): 3.12898
# iter: 54, f: 0.547011, l_inf_norm(grad): 5.07873
# iter: 55, f: 0.543581, l_inf_norm(grad): 6.48883
# iter: 56, f: 0.539373, l_inf_norm(grad): 5.83762
# iter: 57, f: 0.536171, l_inf_norm(grad): 5.46656
# iter: 58, f: 0.530099, l_inf_norm(grad): 4.54782
# iter: 59, f: 0.526822, l_inf_norm(grad): 4.05721
# iter: 60, f: 0.522236, l_inf_norm(grad): 3.21615
# iter: 61, f: 0.519155, l_inf_norm(grad): 2.67129
# iter: 62, f: 0.515287, l_inf_norm(grad): 1.87154
# iter: 63, f: 0.512412, l_inf_norm(grad): 1.32136
# iter: 64, f: 0.508861, l_inf_norm(grad): 1.10837
# iter: 65, f: 0.506079, l_inf_norm(grad): 1.41484
# iter: 66, f: 0.502564, l_inf_norm(grad): 1.849
# iter: 67, f: 0.499723, l_inf_norm(grad): 2.16771
# iter: 68, f: 0.496042, l_inf_norm(grad): 2.63505
# iter: 69, f: 0.492909, l_inf_norm(grad): 3.01821
# iter: 70, f: 0.48875, l_inf_norm(grad): 3.58962
# iter: 71, f: 0.48452, l_inf_norm(grad): 4.25088
# iter: 72, f: 0.476901, l_inf_norm(grad): 5.45821
# iter: 73, f: 0.118719, l_inf_norm(grad): 1.34335
# iter: 74, f: 0.118519, l_inf_norm(grad): 1.60698
# iter: 75, f: 0.10982, l_inf_norm(grad): 1.44933
# iter: 76, f: 0.0640545, l_inf_norm(grad): 4.49718
# iter: 77, f: 0.0573353, l_inf_norm(grad): 2.50052
# iter: 78, f: 0.0516602, l_inf_norm(grad): 1.77956
# iter: 79, f: 0.0356848, l_inf_norm(grad): 0.862632
# iter: 80, f: 0.0274977, l_inf_norm(grad): 1.49951
# iter: 81, f: 0.00660655, l_inf_norm(grad): 0.101734
# iter: 82, f: 0.00492507, l_inf_norm(grad): 0.634436
# iter: 83, f: 0.00428246, l_inf_norm(grad): 1.36975
# iter: 84, f: 0.00397835, l_inf_norm(grad): 1.26673
# iter: 85, f: 0.00113686, l_inf_norm(grad): 0.178749
# iter: 86, f: 0.000642858, l_inf_norm(grad): 0.340178
# iter: 87, f: 3.44622e-05, l_inf_norm(grad): 0.210842
# iter: 88, f: 7.0608e-06, l_inf_norm(grad): 0.0641792
# iter: 89, f: 3.20748e-06, l_inf_norm(grad): 0.056778
# iter: 90, f: 3.073e-07, l_inf_norm(grad): 0.0213285
# iter: 91, f: 5.32969e-08, l_inf_norm(grad): 0.00745115
# iter: 92, f: 4.80363e-10, l_inf_norm(grad): 5.43511e-05
# iter: 93, f: 7.45449e-12, l_inf_norm(grad): 5.84968e-05
# iter: 94, f: 4.17288e-15, l_inf_norm(grad): 2.58696e-06
# iter: 95, f: 3.05047e-18, l_inf_norm(grad): 5.98628e-08

# %% [markdown]
# #### Comments
# We can see that for the 2 quadratic functions, DFP converges in more than 2 iterations because we use inexact line search with Wolfe's rule, which is more cost effective than exact line search; but convergence is still achieved in a small number of iterations in the quadratic case.

# %% [markdown]
# # Part 3: Implement BFGS algorithm
#
# You now need to implement the BFGS algorithm.

# %%
def bfgs(x0, f, f_grad, f_hessian):
    default_step = 0.01
    c1 = 0.0001
    c2 = 0.9
    max_iter = 100
    
    # This variable is used to indicate whether or not we want to print
    # monitoring information (iteration counter, function value and norm of the gradient)
    verbose = True

    all_x_k, all_f_k = list(), list()
    x = x0

    all_x_k.append(x.copy())
    all_f_k.append(f(x))

    H = np.eye(len(x))  # Hessian approximation
    
    grad_x = f_grad(x)
    
    for k in range(1, max_iter + 1):       
        
        ####################################
        # Compute here the search direction
        # d = ...
        ####################################
        d = -linalg.solve(H, grad_x)
        
        # Compute a step size using a line_search to satisfy the
        # strong Wolfe conditions
        step, _, _, new_f, _, new_grad = optimize.line_search(f, f_grad, x,
                                                              d, grad_x,
                                                              c1=1e-4, c2=0.9)

        
        if step is None:
            print("Line search did not converge at iteration %s" % k)
            step = default_step

        ##################################    
        # Compute here the new value of x
        # x = ...
        ##################################
        x += step * d
        #####################################################
        # Update the Hessian approximation   
        # H = ...
        #####################################################
        s = step * d
        s = s[:, None]
        y = new_grad - grad_x
        y = y[:, None]
        H = H + np.dot(y, y.T)/np.dot(y.T, s) - np.dot(H, np.dot(s, np.dot(s.T, H)))/np.dot(s.T, np.dot(H,s))
        
        all_x_k.append(x.copy())
        all_f_k.append(new_f)

        l_inf_norm_grad = np.max(np.abs(new_grad))

        if verbose:
            print('iter: %d, f: %.6g, l_inf_norm(grad): %.6g' %
                  (k, new_f, l_inf_norm_grad))

        if l_inf_norm_grad < 1e-6:
            break
            
        grad_x = new_grad

    return np.array(all_x_k), np.array(all_f_k)

# %%
test_solver(bfgs)
# Out:
# Running solver on case 1
# iter: 1, f: 0.187228, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.0209281, l_inf_norm(grad): 0.11324
# iter: 3, f: 0.00806831, l_inf_norm(grad): 0.0656686
# iter: 4, f: 3.9809e-05, l_inf_norm(grad): 0.00723054
# iter: 5, f: 4.69973e-07, l_inf_norm(grad): 0.000735419
# iter: 6, f: 7.22702e-11, l_inf_norm(grad): 6.78586e-06
# iter: 7, f: 2.47614e-14, l_inf_norm(grad): 1.18656e-07
#
# Running solver on case 2
# iter: 1, f: 0.0978185, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.000159508, l_inf_norm(grad): 0.000290207
# iter: 3, f: 0.000119306, l_inf_norm(grad): 0.00025098
# iter: 4, f: 6.91982e-13, l_inf_norm(grad): 9.54949e-07
#
# Running solver on case 3
# iter: 1, f: 104.123, l_inf_norm(grad): 700.972
# iter: 2, f: 7.59071, l_inf_norm(grad): 26.034
# iter: 3, f: 7.34411, l_inf_norm(grad): 4.87129
# iter: 4, f: 7.29555, l_inf_norm(grad): 8.30631
# iter: 5, f: 6.98403, l_inf_norm(grad): 49.3631
# iter: 6, f: 6.72314, l_inf_norm(grad): 26.9831
# iter: 7, f: 6.31556, l_inf_norm(grad): 14.5499
# iter: 8, f: 5.59349, l_inf_norm(grad): 26.8298
# iter: 9, f: 5.29311, l_inf_norm(grad): 34.9437
# iter: 10, f: 4.57871, l_inf_norm(grad): 21.0185
# iter: 11, f: 3.96296, l_inf_norm(grad): 18.1296
# iter: 12, f: 3.28756, l_inf_norm(grad): 4.93544
# iter: 13, f: 2.77843, l_inf_norm(grad): 12.6122
# iter: 14, f: 2.6077, l_inf_norm(grad): 11.0648
# iter: 15, f: 2.08315, l_inf_norm(grad): 2.44576
# iter: 16, f: 1.86325, l_inf_norm(grad): 10.265
# iter: 17, f: 1.69802, l_inf_norm(grad): 3.80269
# iter: 18, f: 1.49578, l_inf_norm(grad): 3.31517
# iter: 19, f: 1.38214, l_inf_norm(grad): 3.37188
# iter: 20, f: 1.22975, l_inf_norm(grad): 4.98175
# iter: 21, f: 1.06786, l_inf_norm(grad): 9.04305
# iter: 22, f: 0.830936, l_inf_norm(grad): 1.7816
# iter: 23, f: 0.640771, l_inf_norm(grad): 4.16286
# iter: 24, f: 0.535547, l_inf_norm(grad): 6.51712
# iter: 25, f: 0.354951, l_inf_norm(grad): 1.1906
# iter: 26, f: 0.277152, l_inf_norm(grad): 2.72258
# iter: 27, f: 0.248504, l_inf_norm(grad): 5.9946
# iter: 28, f: 0.172188, l_inf_norm(grad): 1.5678
# iter: 29, f: 0.11648, l_inf_norm(grad): 0.969899
# iter: 30, f: 0.0869213, l_inf_norm(grad): 2.84042
# iter: 31, f: 0.0535631, l_inf_norm(grad): 2.97919
# iter: 32, f: 0.0293085, l_inf_norm(grad): 1.60509
# iter: 33, f: 0.0136396, l_inf_norm(grad): 0.904735
# iter: 34, f: 0.0103272, l_inf_norm(grad): 2.01277
# iter: 35, f: 0.00563317, l_inf_norm(grad): 1.37509
# iter: 36, f: 0.00145366, l_inf_norm(grad): 0.258227
# iter: 37, f: 0.000584402, l_inf_norm(grad): 0.884989
# iter: 38, f: 3.9332e-05, l_inf_norm(grad): 0.117654
# iter: 39, f: 1.02109e-06, l_inf_norm(grad): 0.0115504
# iter: 40, f: 1.6916e-08, l_inf_norm(grad): 0.00486102
# iter: 41, f: 5.8541e-12, l_inf_norm(grad): 8.85543e-05
# iter: 42, f: 5.05025e-18, l_inf_norm(grad): 6.48977e-09

# %% [markdown]
# #### Comments
#
# BFGS converges faster than DFP in the quadradic case, and **twice as fast** for the Rosenbrock function, which is due to the fact that BFGS is more robust to the use of inexact line search.
#
# We should however note that our implementation here is naive, because it requires solving the system $d_k = -H_k^{-1}\nabla f(x_k)$ to obtain the step $\rho_k$, which increases the cost of the step computation to $O(n^3)$ (compared with $O(n^2)$ for DFP). An implemetation wih a $O(n^2)$ cost for the step is possible by using the Cholesky factorization of $H_k$, which we do below:

# %%
def bfgs_cholesky(x0, f, f_grad, f_hessian):
    default_step = 0.01
    c1 = 0.0001
    c2 = 0.9
    max_iter = 100
    
    # This variable is used to indicate whether or not we want to print
    # monitoring information (iteration counter, function value and norm of the gradient)
    verbose = True

    all_x_k, all_f_k = list(), list()
    x = x0

    all_x_k.append(x.copy())
    all_f_k.append(f(x))

    H = np.eye(len(x))  # Hessian approximation
    
    grad_x = f_grad(x)
    
    for k in range(1, max_iter + 1):       
        
        ####################################
        # Compute here the search direction
        # d = ...
        ####################################
       
        d = -linalg.cho_solve(linalg.cho_factor(H, lower=True), grad_x)
         
        # Compute a step size using a line_search to satisfy the
        # strong Wolfe conditions
        step, _, _, new_f, _, new_grad = optimize.line_search(f, f_grad, x,
                                                              d, grad_x,
                                                              c1=c1, c2=c2)
 
        if step is None:
            print("Line search did not converge at iteration %s" % k)
            step = default_step

        ##################################    
        # Compute here the new value of x
        # x = ...
        ##################################
        x += step * d
        #####################################################
        # Update the Hessian approximation   
        # H = ...
        #####################################################
        s = step * d
        s = s[:, None]
        y = new_grad - grad_x
        y = y[:, None]
        H = H + np.dot(y, y.T)/np.dot(y.T, s) - np.dot(H, np.dot(s, np.dot(s.T, H)))/np.dot(s.T, np.dot(H,s))
        
        all_x_k.append(x.copy())
        all_f_k.append(new_f)

        l_inf_norm_grad = np.max(np.abs(new_grad))

        if verbose:
            print('iter: %d, f: %.6g, l_inf_norm(grad): %.6g' %
                  (k, new_f, l_inf_norm_grad))

        if l_inf_norm_grad <= 1e-6:
            break
            
        grad_x = new_grad

    return np.array(all_x_k), np.array(all_f_k)

# %%
test_solver(bfgs_cholesky)
# Out:
# Running solver on case 1
# iter: 1, f: 0.187228, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.0209281, l_inf_norm(grad): 0.11324
# iter: 3, f: 0.00806831, l_inf_norm(grad): 0.0656686
# iter: 4, f: 3.9809e-05, l_inf_norm(grad): 0.00723054
# iter: 5, f: 4.69973e-07, l_inf_norm(grad): 0.000735419
# iter: 6, f: 7.22702e-11, l_inf_norm(grad): 6.78586e-06
# iter: 7, f: 2.47614e-14, l_inf_norm(grad): 1.18656e-07
#
# Running solver on case 2
# iter: 1, f: 0.0978185, l_inf_norm(grad): 0.35904
# iter: 2, f: 0.000159508, l_inf_norm(grad): 0.000290207
# iter: 3, f: 0.000119306, l_inf_norm(grad): 0.00025098
# iter: 4, f: 6.91982e-13, l_inf_norm(grad): 9.54949e-07
#
# Running solver on case 3
# iter: 1, f: 104.123, l_inf_norm(grad): 700.972
# iter: 2, f: 7.59071, l_inf_norm(grad): 26.034
# iter: 3, f: 7.34411, l_inf_norm(grad): 4.87129
# iter: 4, f: 7.29555, l_inf_norm(grad): 8.30631
# iter: 5, f: 6.98403, l_inf_norm(grad): 49.3631
# iter: 6, f: 6.72314, l_inf_norm(grad): 26.9831
# iter: 7, f: 6.31556, l_inf_norm(grad): 14.5499
# iter: 8, f: 5.59349, l_inf_norm(grad): 26.8298
# iter: 9, f: 5.29311, l_inf_norm(grad): 34.9437
# iter: 10, f: 4.57871, l_inf_norm(grad): 21.0185
# iter: 11, f: 3.96296, l_inf_norm(grad): 18.1296
# iter: 12, f: 3.28756, l_inf_norm(grad): 4.93544
# iter: 13, f: 2.77843, l_inf_norm(grad): 12.6122
# iter: 14, f: 2.6077, l_inf_norm(grad): 11.0648
# iter: 15, f: 2.08315, l_inf_norm(grad): 2.44576
# iter: 16, f: 1.86325, l_inf_norm(grad): 10.265
# iter: 17, f: 1.69802, l_inf_norm(grad): 3.80269
# iter: 18, f: 1.49578, l_inf_norm(grad): 3.31517
# iter: 19, f: 1.38214, l_inf_norm(grad): 3.37188
# iter: 20, f: 1.22975, l_inf_norm(grad): 4.98175
# iter: 21, f: 1.06786, l_inf_norm(grad): 9.04305
# iter: 22, f: 0.830936, l_inf_norm(grad): 1.7816
# iter: 23, f: 0.640771, l_inf_norm(grad): 4.16286
# iter: 24, f: 0.535547, l_inf_norm(grad): 6.51712
# iter: 25, f: 0.354951, l_inf_norm(grad): 1.1906
# iter: 26, f: 0.277152, l_inf_norm(grad): 2.72258
# iter: 27, f: 0.248504, l_inf_norm(grad): 5.9946
# iter: 28, f: 0.172188, l_inf_norm(grad): 1.5678
# iter: 29, f: 0.11648, l_inf_norm(grad): 0.969899
# iter: 30, f: 0.0869213, l_inf_norm(grad): 2.84042
# iter: 31, f: 0.0535631, l_inf_norm(grad): 2.97919
# iter: 32, f: 0.0293085, l_inf_norm(grad): 1.60509
# iter: 33, f: 0.0136396, l_inf_norm(grad): 0.904735
# iter: 34, f: 0.0103272, l_inf_norm(grad): 2.01277
# iter: 35, f: 0.00563317, l_inf_norm(grad): 1.37509
# iter: 36, f: 0.00145366, l_inf_norm(grad): 0.258227
# iter: 37, f: 0.000584402, l_inf_norm(grad): 0.884989
# iter: 38, f: 3.9332e-05, l_inf_norm(grad): 0.117654
# iter: 39, f: 1.02109e-06, l_inf_norm(grad): 0.0115504
# iter: 40, f: 1.6916e-08, l_inf_norm(grad): 0.00486102
# iter: 41, f: 5.8541e-12, l_inf_norm(grad): 8.85543e-05
# iter: 42, f: 5.05025e-18, l_inf_norm(grad): 6.48977e-09

# %% [markdown]
# # Part 4: Do the same now with scipy implementation of BFGS and L-BFGS

# %%
from scipy.optimize import fmin_bfgs, fmin_l_bfgs_b

# BFGS   
def bfgs_scipy(x0, f, f_grad, f_hessian):
    list_x = list()
    list_f = list()
    def call_back(x):
        list_x.append(x.copy())
        f_k = f(x.copy())
        list_f.append(f_k)
        print('iter: %d, f: %.6g'%(len(list_x), f_k))

    fmin_bfgs(f=f, x0=x0, fprime=f_grad, callback=call_back, gtol=1e-6) 
    return np.array(list_x), np.array(list_f)

test_solver(bfgs_scipy)

# %% [markdown]
# #### Comments
#
# The scicpy implementation of BFGS converges in the same number of iterations as our implementation for the quadratic case, but it is **almost twice as fast** for the rosenbroack function. The implementation if BFGS algorithm in scipy is working with the approximation of the inverse of the Hessian rather than approximations of the Hessian.

# %%
#L-BFGS
def l_bfgs_scipy(x0, f, f_grad, f_hessian):
    list_x = list()
    list_f = list()
    def call_back(x):
        list_x.append(x.copy())
        f_k = f(x.copy())
        list_f.append(f_k)
        print('iter: %d, f: %.6g'%(len(list_x), f_k))
        
    fmin_l_bfgs_b(func=f, x0=x0, fprime=f_grad, callback=call_back,  pgtol=1e-6)
    return np.array(list_x), np.array(list_f)
 
test_solver(l_bfgs_scipy)
